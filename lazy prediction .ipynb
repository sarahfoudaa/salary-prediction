# %%
# %cd /content/drive/MyDrive/machine_learning_projects/salary_prediction/salary-prediction
# Out:
# /content/drive/MyDrive/machine_learning_projects/salary_prediction/salary-prediction

# %%
# !pip install lazypredict

# %%
import pandas as pd

# %%
X_train = pd.read_csv('/content/drive/MyDrive/machine_learning_projects/salary_prediction/data/selected/X_train')
y_train = pd.read_csv('/content/drive/MyDrive/machine_learning_projects/salary_prediction/data/selected/y_train')

# %%
from lazypredict.Supervised import LazyRegressor

# %%
from custom_funcs import splitModeling
X_train, X_test, y_train, y_test = splitModeling(X_train, y_train, 0.1)

# %%
reg = LazyRegressor(verbose = 0, ignore_warnings=False, custom_metric= None)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
# Out:
#   5%|▍         | 2/42 [00:00<00:03, 12.97it/s]
# AdaBoostRegressor model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
# BayesianRidge model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
#  14%|█▍        | 6/42 [00:00<00:01, 24.69it/s]
# ElasticNetCV model failed to execute
# For multi-task outputs, use MultiTaskElasticNetCV
#  21%|██▏       | 9/42 [00:01<00:05,  6.02it/s]
# GammaRegressor model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
#  36%|███▌      | 15/42 [00:01<00:03,  7.95it/s]
# GradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
# HistGradientBoostingRegressor model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
# HuberRegressor model failed to execute
# y should be a 1d array, got an array of shape (1809, 2) instead.
# ...

# %%
models
# Out:
#                             Adjusted R-Squared  R-Squared   RMSE  Time Taken
# Model
# OrthogonalMatchingPursuit                 0.98       0.98   0.05        0.03
# RANSACRegressor                           0.98       0.98   0.05        0.04
# Lars                                      0.98       0.98   0.05        0.05
# LinearRegression                          0.98       0.98   0.05        0.07
# TransformedTargetRegressor                0.98       0.98   0.05        0.05
# RidgeCV                                   0.98       0.98   0.06        0.02
# Ridge                                     0.98       0.98   0.24        0.01
# XGBRegressor                              0.98       0.98   2.50        0.22
# KNeighborsRegressor                       0.92       0.92  93.70        0.04
# RandomForestRegressor                     0.58       0.60   0.57        0.85
# ExtraTreesRegressor                       0.57       0.59   0.38        0.89
# ...

# %%
predictions
# Out:
#                             Adjusted R-Squared  R-Squared   RMSE  Time Taken
# Model
# OrthogonalMatchingPursuit                 0.98       0.98   0.05        0.03
# RANSACRegressor                           0.98       0.98   0.05        0.04
# Lars                                      0.98       0.98   0.05        0.05
# LinearRegression                          0.98       0.98   0.05        0.07
# TransformedTargetRegressor                0.98       0.98   0.05        0.05
# RidgeCV                                   0.98       0.98   0.06        0.02
# Ridge                                     0.98       0.98   0.24        0.01
# XGBRegressor                              0.98       0.98   2.50        0.22
# KNeighborsRegressor                       0.92       0.92  93.70        0.04
# RandomForestRegressor                     0.58       0.60   0.57        0.85
# ExtraTreesRegressor                       0.57       0.59   0.38        0.89
# ...
